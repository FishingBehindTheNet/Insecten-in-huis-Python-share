# %% [markdown]
# # **1.1.1 Extractie rasterdata binnen buffers**
# Om de invloed van landgebruik op de waarnemingen te onderzoeken is er data verzameld uit de raster kaart [Landelijk Grondgebruikbestand Nederland uit 2018 van de Wageningen Universiteit](https://www.wur.nl/nl/Onderzoek-Resultaten/Onderzoeksinstituten/Environmental-Research/Faciliteiten-tools/Kaarten-en-GIS-bestanden/Landelijk-Grondgebruik-Nederland/Versies-bestanden/LGN2018.htm). Deze kaart geeft, met een nauwkeurigheid van 5 bij 5 meter, aan wat het landgebruik over heel Nederland is. Met behulp van dit script is rondom de locatie van iedere waarneming binnen een radius van 100 meter (verstelbaar) bekeken wat het landgebruik is volgens het eerder genoemd Landelijk Grondgebruikbestand Nederland. De output geeft het aandeel dat ieder landgebruik type inneemt binnen de buffer in procenten. Daarnaast bied het de mogelijkheid deze output te clusteren in vooraf gemaakte groepen.

# %%
# Laad de benodigde ondersteunende bibliotheken in
from shapely.geometry import shape, Point
from pyproj import CRS as ProjCRS
from rasterio.mask import mask
from pathlib import Path
import geopandas as gpd
import pandas as pd
import numpy as np
import rasterio
import pyproj
import sys
import os

# %% [markdown]
# ## Intro en settings
# Het doel van deze code is om omgevingsdata rondom coördinaten op te halen. Deze coördinaten moeten gegeven worden in een Excel bestand (.xlsx). De locaties moeten gegeven worden in Rijksdriehoekscoördinaten (RD-coördinaten) waarbij de X en Y component in losse kolommen gegeven wordt. Het gegeven Excel bestand hoeft verder niet leeg van data te zijn en kan zelfs meerdere tabbladen bevatten. Om dit te accommoderen wordt wel gevraagd om de naam van het tabblad en de kolommen met de coördinaten op voorhand te selecteren.

# %% [markdown]
# **Excel:**

# %%
# Vul hieronder het pad naar je Excel bestand in. 
# Laat hierbij het "Path(r"..")" intact.
Excel_file = Path(r"Input_data/TestInput.xlsx")

# Geef hier de naam van de Excel sheet met de coördinaten voor de extractie.
Excel_sheet = "Sheet1"

# Geef hier de Kolommen van de Excel sheet met coördinaten. 
# Dit script werkt voor RD coördinaten en gaat er vanuit dat de X en Y coördinaten in losse kolommen staan
Excel_X_coördinaat = "RDX"
Excel_Y_coördinaat = "RDY"

# Defineer het coordinaten systeem van de observaties en van de rasterkaart
Waarnemingen_crs = pyproj.CRS("EPSG:28992")  # Amersfoort RD New

# %% [markdown]
# De eerder genoemde omgevingsdata is afkomstig van een, door de gebruiker aangeleverde, raster kaart (.tif). De resolutie van deze kaart hoeft geen specifieke nauwkeurigheid te hebben maar houd er rekening mee dat een hogere resolutie resulteert in een hogere nauwkeurigheid in de output.
#
#
# Daarnaast is een Legenda nodig om de pixelwaarde van de rasterdata te kunnen interpreteren. Deze legenda wordt vaak in een los bestandstype (bijvoorbeeld .sld) opgeslagen. Dit type bestand is moeilijk in te lezen in python, er is daarom voor een handmatig alternatief gekozen met een legenda in de vorm van een Excel bestand wat door de gebruiker op voorhand aangemaakt moet worden. Open hiervoor de kaartlaag in een GIS programma naar keuze en kopieer de legenda zoals hier onder is voorgedaan. De kolom "Categorie" is bedoelt voor het clusteren van de output. Wanneer meerdere regels een gelijke waarde krijgen in deze kolom wordt een extra gezamenlijke kolom aangemaakt in de output waar deze waarden opgeteld in verwerkt worden. Deze kolom kan naar wens ook volledig weg gelaten worden wat verder geen gevolgen voor het functioneren van de code heeft.
#
# <style>
# td:first-child {{
#     text-align: right;
# }}
# td:last-child {{
#     text-align: left;
# }}
# </style>
# <table>
# <tr>
#     <td>Label waarde als aangegeven bij de legenda</td>
#     <td>Label naam als aangeven bij de legenda</td>
#     <td>Optionele categorie waarbinnen de labels vallen</td>
# </tr>
# <tr>
#     <td><b>Value</b></td>
#     <td><b>Name</b></td>
#     <td><b>Categorie <code style="color:red;">(Niet verplicht)</code></b></td>
# </tr>
# <tr>
#     <td>47</td>
#     <td>overig gras</td>
#     <td>Gras</td>
# </tr>
# <tr>
#     <td>61</td>
#     <td>boomkwekerijen</td>
#     <td>Agrarisch</td>
# </tr>
# <tr>
#     <td>62</td>
#     <td>fruitkwekerijen</td>
#     <td>Agrarisch</td>
# </tr>
# <tr>
#     <td>251</td>
#     <td>hoofdinfrastructuur en spoorbaanlichamen</td>
#     <td>Bebouwing</td>
# </tr>
#     <td>etc.</td>
#     <td>etc.</td>
#     <td>etc.</td>
# </tr>

# %% [markdown]
# **Kaart / Shape file:**

# %%
# Vul hieronder het pad naar je raster kaart.tif in. 
# Laat hierbij het "Path(r"..")" intact.
buffer_kaart_pad = Path(r"Input_data/LGN2018/LGN2018.tif")

# Vul hieronder het pad naar de handgemaakte legenda van je kaart in. 
# Laat hierbij het "Path(r"..")" intact.
kaart_Legenda = Path(r"Input_data/List_LGN.xlsx")

# %% [markdown]
# Als laatste moet de buffer grootte opgegeven worden. Deze waarde wordt gelezen als de radius (halve diameter) van de cirkel om iedere waarneming heen in meters.
#
# <code style="color:red;"><b>LET OP:</b> Waarnemingen zonder (valide) Coördinaten of Waarnemingen die buiten de kaart vallen worden niet weergegeven in de output </code>

# %% [markdown]
# **Buffer:**

# %%
# Vul hier de Radius in voor de buffer. (In meters)
buffer_radius = 100

# %% [markdown]
# ## Het script

# %%
# Laad de opgegeven bestanden in
Excel_df = pd.read_excel(io = Excel_file, sheet_name = Excel_sheet)
buffer_kaart = rasterio.open(buffer_kaart_pad)
kaart_Legenda_df = pd.read_excel(kaart_Legenda, header=0)

# Controle of coordinaten systemen hetzelfde zijn
if Waarnemingen_crs != buffer_kaart.crs:
    # Maakt een transformer
    transformer = pyproj.Transformer.from_crs(Waarnemingen_crs, buffer_kaart.crs, always_xy=True)
    # Voert de transformatie uit en maakt nieuwe kolommen
    Excel_df['Converted_X'], Excel_df['Converted_Y'] = transformer.transform(Excel_df[Excel_X_coördinaat], Excel_df[Excel_Y_coördinaat])
    # Leest de coördinaten van de waarnemingen in en converteer de coördinaten zodat ze later naar buffers omgezet kunnen worden
    Excel_buffers = gpd.GeoDataFrame(
        geometry = [
            Point(X, Y) for X, Y in zip(Excel_df['Converted_X'], Excel_df['Converted_Y'])
        ], crs=buffer_kaart.crs)
else:
    Excel_buffers = gpd.GeoDataFrame(
        geometry = [
            Point(X, Y) for X, Y in zip(Excel_df[Excel_X_coördinaat], Excel_df[Excel_Y_coördinaat])
        ], crs=buffer_kaart.crs)

# Genereert buffers rondom iedere waarneming met de aangegeven radius
Excel_buffers = Excel_buffers.buffer(buffer_radius)

# maakt een dictionary om output voor losse label aandeel per waarneming op te slaan
data_dict_name = {}
# maakt een dictionary om output voor gegroepeerde label aandeel per waarneming op te slaan
data_dict_Grouped = {}
# Variable om de tel van de print-functie bij te houden. 
# Begint bij -1 zodat er aan het begin van de loop direct +1 toegevoegd kan worden en 
# tegelijkertijd te kunnen compenseren voor het tellen vanaf 0.
counter2 = 0
Counter = -1
#Bepaalt de max waarde van de printfunctie
counter_max = len(Excel_buffers.index)

# Bekijkt datapunten per waarneming
for buffer in Excel_buffers:
    # houd bij welke buffer verwerkt wordt als een indicatie van voortgang in de vorm van een geprinte update
    Counter += 1
    print(f"working on buffer {Counter} of {counter_max - 1}")

    # Checkt of de buffer een waarde heeft. Wanneer een waarneming geen coördinaten heeft wordt er geen buffer gegenereerd in de eerdere stap maar dit veroorzaakt geen error.
    # om deze gevallen te kunnen afvangen word hier gecheckt of de buffer gegenereerd is.
    if buffer:
        # De "try:" word gebruikt om het overlap van de buffer en kaart te testen. Wanneer de kaart geen overlap vertoont met de buffer 
        # veroorzaakt dit een error. De "try:" zorgt dat de code hierdoor niet stopt maar deze waarde over kan slaan nadat het een error
        # tegenkomt.
        try:
            # genereert een GeoDataFrame(GDF) met alle "pixels" uit de kaartlaag die overlappen met de geselecteerde buffer
            kaart_buffer, _ = mask(buffer_kaart, [shape(buffer)], crop=True)

            # Checkt of er een verwijzing naar de huidige buffer is in data_dict_name en maakt deze anders aan in zowel data_dict_name als 
            # in data_dict_Grouped. 
            if Counter not in data_dict_name:
                data_dict_name[Counter] = {}
                data_dict_Grouped[Counter] = {}
                counter2 += 1
            
            # Kijkt per regel van de legenda hoe vaak de waarde uit deze regel voorkomt in het nieuw gemaakte GDF
            for index, row in kaart_Legenda_df.iterrows():
                aantal = np.count_nonzero(kaart_buffer == row["Value"])
                
                # Slaat het gevonden aantal op onder het labelnaam behorende tot deze waarde/regel
                data_dict_name[Counter][row["Name"]] = aantal
                
                # Controleert of er categorieën in de legenda aangegeven zijn. 
                # als dit het geval is word gecontroleerd of er een verwijzing is naar de categorie in de data_dict_Grouped variabelen onder de counter value.
                # en maakt deze anders aan met value=0 zodat meerdere verwijzingen naar een zelfde categorie elkaar niet overschrijven
                if "Categorie" in kaart_Legenda_df.columns and row["Categorie"]:
                    if not row["Categorie"] in data_dict_Grouped[Counter]:
                        data_dict_Grouped[Counter][row["Categorie"]] = 0
                    data_dict_Grouped[Counter][row["Categorie"]] += aantal
        except:
            # print een mogelijke verklaring voor het falen van de datacollectie en gaat dan veder naar de volgende waarde in de loop.
            print(f"buffer {Counter} mislukt, mogelijk geen overlap tussen buffer en kaartlaag")
            pass
    # Als er geen buffer gegenereerd is word een mogelijke verklaring van het probleem geprint en verder gegaan zonder data te genereren     
    else:
        print(f"buffer {Counter} mislukt, mogelijk geen coördinaten")

# geeft feedback wanneer er geen buffers worden aangemaakt
if counter2 == 0:
        print("!!!ERROR: Coördinatensysteem van de waarnemingen zijn verkeerd of de waarnemingen vallen niet binnen het raster!!!")
        sys.exit()

# print een proces update naar de gebruiker
print("Calculating...")

# genereert een dataframe van de data in dictionary vorm en maakt een kolom met totaal aantal pixels per waarneming
# zodat waardes omgerekend kunnen worden naar procenten.
output_name_df = pd.DataFrame(data_dict_name)
output_name_df.loc["Sum"] = output_name_df.sum()
output_name_df = output_name_df.T

# kopieert de index van output_name_df naar een leeg dataframe waar de omgerekende output in opgeslagen gaat worden. 
output_procent_df = pd.DataFrame(index=output_name_df.index)

# berekend voor iedere legenda waarde het aandeel van de totale buffer in procent en slaat deze op in de output dataframe
for index, row in kaart_Legenda_df.iterrows():
    output_procent_df[row["Name"]]= output_name_df[row["Name"]]/output_name_df["Sum"]

# Controleer of er categorieën in de legenda aangegeven zijn.
# Als dit het geval is maakt het de zelfde berekeningen als voor output_name_df maar voor de output_categorie_df
if  "Categorie" in kaart_Legenda_df.columns:
    output_categorie_df = pd.DataFrame(data_dict_Grouped)
    output_categorie_df.loc["Sum"] = output_categorie_df.sum()
    output_categorie_df = output_categorie_df.T

    for columns in output_categorie_df.columns:
        if not columns == "Sum":
            output_procent_df[f"C_{columns}"]= output_categorie_df[columns] / output_categorie_df["Sum"]

# print een proces update naar de gebruiker
print("Saving data...")

# Verwijderd de lege rijen uit de output_procent_df zodat deze in de volgende regel samengevoegd kan worden met originele data mislukte waarnemingen in de output weer te geven.
output_procent_df = output_procent_df.dropna(axis="index", how="all")
all_data = pd.merge(Excel_df, output_procent_df, left_index=True, right_index=True, how='inner')

# Checkt of er een Output mapje op de locatie van de code staat en maakt deze anders aan
if not os.path.exists("Output"):
    os.makedirs("Output")

# Slaat de output op in een Excel bestand in Output Dir. print de locatie van de output naar de gebruiker.
all_data.to_excel(rf"Output/{Excel_file.stem}_{buffer_kaart_pad.stem}_{buffer_radius}.xlsx")
print(f"file saved at: {os.getcwd()}/Output/{Excel_file.stem}_{buffer_kaart_pad.stem}_{buffer_radius}.xlsx")
# Out:
# working on buffer 0 of 2649
# working on buffer 1 of 2649
# working on buffer 2 of 2649
# working on buffer 3 of 2649
# working on buffer 4 of 2649
# working on buffer 5 of 2649
# working on buffer 6 of 2649
# working on buffer 7 of 2649
# working on buffer 8 of 2649
# working on buffer 9 of 2649
# working on buffer 10 of 2649
# working on buffer 11 of 2649
# working on buffer 12 of 2649
# working on buffer 13 of 2649
# working on buffer 14 of 2649
# working on buffer 15 of 2649
# working on buffer 16 of 2649
# working on buffer 17 of 2649
# working on buffer 18 of 2649
# working on buffer 19 of 2649
# working on buffer 20 of 2649
# working on buffer 21 of 2649
# working on buffer 22 of 2649
# working on buffer 23 of 2649
# working on buffer 24 of 2649
# working on buffer 25 of 2649
# working on buffer 26 of 2649
# working on buffer 27 of 2649
# working on buffer 28 of 2649
# working on buffer 29 of 2649
# working on buffer 30 of 2649
# working on buffer 31 of 2649
# working on buffer 32 of 2649
# working on buffer 33 of 2649
# working on buffer 34 of 2649
# working on buffer 35 of 2649
# working on buffer 36 of 2649
# working on buffer 37 of 2649
# working on buffer 38 of 2649
# working on buffer 39 of 2649
# working on buffer 40 of 2649
# working on buffer 41 of 2649
# working on buffer 42 of 2649
# working on buffer 43 of 2649
# working on buffer 44 of 2649
# working on buffer 45 of 2649
# working on buffer 46 of 2649
# working on buffer 47 of 2649
# working on buffer 48 of 2649
# working on buffer 49 of 2649
# working on buffer 50 of 2649
# working on buffer 51 of 2649
# working on buffer 52 of 2649
# working on buffer 53 of 2649
# working on buffer 54 of 2649
# working on buffer 55 of 2649
# working on buffer 56 of 2649
# working on buffer 57 of 2649
# working on buffer 58 of 2649
# working on buffer 59 of 2649
# working on buffer 60 of 2649
# working on buffer 61 of 2649
# working on buffer 62 of 2649
# working on buffer 63 of 2649
# working on buffer 64 of 2649
# working on buffer 65 of 2649
# working on buffer 66 of 2649
# working on buffer 67 of 2649
# working on buffer 68 of 2649
# working on buffer 69 of 2649
# working on buffer 70 of 2649
# working on buffer 71 of 2649
# working on buffer 72 of 2649
# working on buffer 73 of 2649
# working on buffer 74 of 2649
# working on buffer 75 of 2649
# working on buffer 76 of 2649
# working on buffer 77 of 2649
# working on buffer 78 of 2649
# working on buffer 79 of 2649
# working on buffer 80 of 2649
# working on buffer 81 of 2649
# working on buffer 82 of 2649
# working on buffer 83 of 2649
# working on buffer 84 of 2649
# working on buffer 85 of 2649
# working on buffer 86 of 2649
# working on buffer 87 of 2649
# working on buffer 88 of 2649
# working on buffer 89 of 2649
# working on buffer 90 of 2649
# working on buffer 91 of 2649
# working on buffer 92 of 2649
# working on buffer 93 of 2649
# working on buffer 94 of 2649
# working on buffer 95 of 2649
# working on buffer 96 of 2649
# working on buffer 97 of 2649
# working on buffer 98 of 2649
# working on buffer 99 of 2649
# working on buffer 100 of 2649
# working on buffer 101 of 2649
# working on buffer 102 of 2649
# working on buffer 103 of 2649
# working on buffer 104 of 2649
# working on buffer 105 of 2649
# working on buffer 106 of 2649
# working on buffer 107 of 2649
# working on buffer 108 of 2649
# working on buffer 109 of 2649
# working on buffer 110 of 2649
# working on buffer 111 of 2649
# working on buffer 112 of 2649
# working on buffer 113 of 2649
# working on buffer 114 of 2649
# working on buffer 115 of 2649
# working on buffer 116 of 2649
# working on buffer 117 of 2649
# working on buffer 118 of 2649
# working on buffer 119 of 2649
# working on buffer 120 of 2649
# working on buffer 121 of 2649
# working on buffer 122 of 2649
# working on buffer 123 of 2649
# working on buffer 124 of 2649
# working on buffer 125 of 2649
# working on buffer 126 of 2649
# working on buffer 127 of 2649
# working on buffer 128 of 2649
# working on buffer 129 of 2649
# working on buffer 130 of 2649
# working on buffer 131 of 2649
# working on buffer 132 of 2649
# working on buffer 133 of 2649
# working on buffer 134 of 2649
# working on buffer 135 of 2649
# working on buffer 136 of 2649
# working on buffer 137 of 2649
# working on buffer 138 of 2649
# working on buffer 139 of 2649
# working on buffer 140 of 2649
# working on buffer 141 of 2649
# working on buffer 142 of 2649
# working on buffer 143 of 2649
# working on buffer 144 of 2649
# working on buffer 145 of 2649
# working on buffer 146 of 2649
# working on buffer 147 of 2649
# working on buffer 148 of 2649
# working on buffer 149 of 2649
# working on buffer 150 of 2649
# working on buffer 151 of 2649
# working on buffer 152 of 2649
# working on buffer 153 of 2649
# working on buffer 154 of 2649
# working on buffer 155 of 2649
# working on buffer 156 of 2649
# working on buffer 157 of 2649
# working on buffer 158 of 2649
# working on buffer 159 of 2649
# working on buffer 160 of 2649
# working on buffer 161 of 2649
# working on buffer 162 of 2649
# working on buffer 163 of 2649
# working on buffer 164 of 2649
# working on buffer 165 of 2649
# working on buffer 166 of 2649
# working on buffer 167 of 2649
# working on buffer 168 of 2649
# working on buffer 169 of 2649
# working on buffer 170 of 2649
# working on buffer 171 of 2649
# working on buffer 172 of 2649
# working on buffer 173 of 2649
# working on buffer 174 of 2649
# working on buffer 175 of 2649
# working on buffer 176 of 2649
# working on buffer 177 of 2649
# working on buffer 178 of 2649
# working on buffer 179 of 2649
# working on buffer 180 of 2649
# working on buffer 181 of 2649
# working on buffer 182 of 2649
# working on buffer 183 of 2649
# working on buffer 184 of 2649
# working on buffer 185 of 2649
# working on buffer 186 of 2649
# working on buffer 187 of 2649
# working on buffer 188 of 2649
# working on buffer 189 of 2649
# working on buffer 190 of 2649
# working on buffer 191 of 2649
# working on buffer 192 of 2649
# working on buffer 193 of 2649
# working on buffer 194 of 2649
# working on buffer 195 of 2649
# working on buffer 196 of 2649
# working on buffer 197 of 2649
# working on buffer 198 of 2649
# working on buffer 199 of 2649
# working on buffer 200 of 2649
# working on buffer 201 of 2649
# working on buffer 202 of 2649
# working on buffer 203 of 2649
# working on buffer 204 of 2649
# working on buffer 205 of 2649
# working on buffer 206 of 2649
# working on buffer 207 of 2649
# working on buffer 208 of 2649
# working on buffer 209 of 2649
# working on buffer 210 of 2649
# working on buffer 211 of 2649
# working on buffer 212 of 2649
# working on buffer 213 of 2649
# working on buffer 214 of 2649
# working on buffer 215 of 2649
# working on buffer 216 of 2649
# working on buffer 217 of 2649
# working on buffer 218 of 2649
# working on buffer 219 of 2649
# working on buffer 220 of 2649
# working on buffer 221 of 2649
# working on buffer 222 of 2649
# working on buffer 223 of 2649
# working on buffer 224 of 2649
# working on buffer 225 of 2649
# working on buffer 226 of 2649
# working on buffer 227 of 2649
# working on buffer 228 of 2649
# working on buffer 229 of 2649
# working on buffer 230 of 2649
# working on buffer 231 of 2649
# working on buffer 232 of 2649
# working on buffer 233 of 2649
# working on buffer 234 of 2649
# working on buffer 235 of 2649
# working on buffer 236 of 2649
# working on buffer 237 of 2649
# working on buffer 238 of 2649
# working on buffer 239 of 2649
# working on buffer 240 of 2649
# working on buffer 241 of 2649
# working on buffer 242 of 2649
# working on buffer 243 of 2649
# working on buffer 244 of 2649
# working on buffer 245 of 2649
# working on buffer 246 of 2649
# working on buffer 247 of 2649
# working on buffer 248 of 2649
# working on buffer 249 of 2649
# working on buffer 250 of 2649
# working on buffer 251 of 2649
# working on buffer 252 of 2649
# working on buffer 253 of 2649
# working on buffer 254 of 2649
# working on buffer 255 of 2649
# working on buffer 256 of 2649
# working on buffer 257 of 2649
# working on buffer 258 of 2649
# working on buffer 259 of 2649
# working on buffer 260 of 2649
# working on buffer 261 of 2649
# working on buffer 262 of 2649
# working on buffer 263 of 2649
# working on buffer 264 of 2649
# working on buffer 265 of 2649
# working on buffer 266 of 2649
# working on buffer 267 of 2649
# working on buffer 268 of 2649
# working on buffer 269 of 2649
# working on buffer 270 of 2649
# working on buffer 271 of 2649
# working on buffer 272 of 2649
# working on buffer 273 of 2649
# working on buffer 274 of 2649
# working on buffer 275 of 2649
# working on buffer 276 of 2649
# working on buffer 277 of 2649
# working on buffer 278 of 2649
# working on buffer 279 of 2649
# working on buffer 280 of 2649
# working on buffer 281 of 2649
# working on buffer 282 of 2649
# working on buffer 283 of 2649
# working on buffer 284 of 2649
# working on buffer 285 of 2649
# working on buffer 286 of 2649
# working on buffer 287 of 2649
# working on buffer 288 of 2649
# working on buffer 289 of 2649
# working on buffer 290 of 2649
# working on buffer 291 of 2649
# working on buffer 292 of 2649
# working on buffer 293 of 2649
# working on buffer 294 of 2649
# working on buffer 295 of 2649
# working on buffer 296 of 2649
# working on buffer 297 of 2649
# working on buffer 298 of 2649
# working on buffer 299 of 2649
# working on buffer 300 of 2649
# working on buffer 301 of 2649
# working on buffer 302 of 2649
# working on buffer 303 of 2649
# working on buffer 304 of 2649
# working on buffer 305 of 2649
# working on buffer 306 of 2649
# working on buffer 307 of 2649
# working on buffer 308 of 2649
# working on buffer 309 of 2649
# working on buffer 310 of 2649
# working on buffer 311 of 2649
# working on buffer 312 of 2649
# working on buffer 313 of 2649
# working on buffer 314 of 2649
# working on buffer 315 of 2649
# working on buffer 316 of 2649
# working on buffer 317 of 2649
# working on buffer 318 of 2649
# working on buffer 319 of 2649
# working on buffer 320 of 2649
# working on buffer 321 of 2649
# working on buffer 322 of 2649
# working on buffer 323 of 2649
# working on buffer 324 of 2649
# working on buffer 325 of 2649
# working on buffer 326 of 2649
# working on buffer 327 of 2649
# working on buffer 328 of 2649
# working on buffer 329 of 2649
# working on buffer 330 of 2649
# working on buffer 331 of 2649
# working on buffer 332 of 2649
# working on buffer 333 of 2649
# working on buffer 334 of 2649
# working on buffer 335 of 2649
# working on buffer 336 of 2649
# working on buffer 337 of 2649
# working on buffer 338 of 2649
# working on buffer 339 of 2649
# working on buffer 340 of 2649
# working on buffer 341 of 2649
# working on buffer 342 of 2649
# working on buffer 343 of 2649
# working on buffer 344 of 2649
# working on buffer 345 of 2649
# working on buffer 346 of 2649
# working on buffer 347 of 2649
# working on buffer 348 of 2649
# working on buffer 349 of 2649
# working on buffer 350 of 2649
# working on buffer 351 of 2649
# working on buffer 352 of 2649
# working on buffer 353 of 2649
# working on buffer 354 of 2649
# working on buffer 355 of 2649
# working on buffer 356 of 2649
# working on buffer 357 of 2649
# working on buffer 358 of 2649
# working on buffer 359 of 2649
# working on buffer 360 of 2649
# working on buffer 361 of 2649
# working on buffer 362 of 2649
# working on buffer 363 of 2649
# working on buffer 364 of 2649
# working on buffer 365 of 2649
# working on buffer 366 of 2649
# working on buffer 367 of 2649
# working on buffer 368 of 2649
# working on buffer 369 of 2649
# working on buffer 370 of 2649
# working on buffer 371 of 2649
# working on buffer 372 of 2649
# working on buffer 373 of 2649
# working on buffer 374 of 2649
# working on buffer 375 of 2649
# working on buffer 376 of 2649
# working on buffer 377 of 2649
# working on buffer 378 of 2649
# working on buffer 379 of 2649
# working on buffer 380 of 2649
# working on buffer 381 of 2649
# working on buffer 382 of 2649
# working on buffer 383 of 2649
# working on buffer 384 of 2649
# working on buffer 385 of 2649
# working on buffer 386 of 2649
# working on buffer 387 of 2649
# working on buffer 388 of 2649
# working on buffer 389 of 2649
# working on buffer 390 of 2649
# working on buffer 391 of 2649
# working on buffer 392 of 2649
# working on buffer 393 of 2649
# working on buffer 394 of 2649
# working on buffer 395 of 2649
# working on buffer 396 of 2649
# working on buffer 397 of 2649
# working on buffer 398 of 2649
# working on buffer 399 of 2649
# working on buffer 400 of 2649
# working on buffer 401 of 2649
# working on buffer 402 of 2649
# working on buffer 403 of 2649
# working on buffer 404 of 2649
# working on buffer 405 of 2649
# working on buffer 406 of 2649
# working on buffer 407 of 2649
# working on buffer 408 of 2649
# working on buffer 409 of 2649
# working on buffer 410 of 2649
# working on buffer 411 of 2649
# working on buffer 412 of 2649
# working on buffer 413 of 2649
# working on buffer 414 of 2649
# working on buffer 415 of 2649
# working on buffer 416 of 2649
# working on buffer 417 of 2649
# working on buffer 418 of 2649
# working on buffer 419 of 2649
# working on buffer 420 of 2649
# working on buffer 421 of 2649
# working on buffer 422 of 2649
# working on buffer 423 of 2649
# working on buffer 424 of 2649
# working on buffer 425 of 2649
# working on buffer 426 of 2649
# working on buffer 427 of 2649
# working on buffer 428 of 2649
# working on buffer 429 of 2649
# working on buffer 430 of 2649
# working on buffer 431 of 2649
# working on buffer 432 of 2649
# working on buffer 433 of 2649
# working on buffer 434 of 2649
# working on buffer 435 of 2649
# working on buffer 436 of 2649
# working on buffer 437 of 2649
# working on buffer 438 of 2649
# working on buffer 439 of 2649
# working on buffer 440 of 2649
# working on buffer 441 of 2649
# working on buffer 442 of 2649
# working on buffer 443 of 2649
# working on buffer 444 of 2649
# working on buffer 445 of 2649
# working on buffer 446 of 2649
# working on buffer 447 of 2649
# working on buffer 448 of 2649
# working on buffer 449 of 2649
# working on buffer 450 of 2649
# working on buffer 451 of 2649
# working on buffer 452 of 2649
# working on buffer 453 of 2649
# working on buffer 454 of 2649
# working on buffer 455 of 2649
# working on buffer 456 of 2649
# working on buffer 457 of 2649
# working on buffer 458 of 2649
# working on buffer 459 of 2649
# working on buffer 460 of 2649
# working on buffer 461 of 2649
# working on buffer 462 of 2649
# working on buffer 463 of 2649
# working on buffer 464 of 2649
# working on buffer 465 of 2649
# working on buffer 466 of 2649
# working on buffer 467 of 2649
# working on buffer 468 of 2649
# working on buffer 469 of 2649
# working on buffer 470 of 2649
# working on buffer 471 of 2649
# working on buffer 472 of 2649
# working on buffer 473 of 2649
# working on buffer 474 of 2649
# working on buffer 475 of 2649
# working on buffer 476 of 2649
# working on buffer 477 of 2649
# working on buffer 478 of 2649
# working on buffer 479 of 2649
# working on buffer 480 of 2649
# working on buffer 481 of 2649
# working on buffer 482 of 2649
# working on buffer 483 of 2649
# working on buffer 484 of 2649
# working on buffer 485 of 2649
# working on buffer 486 of 2649
# working on buffer 487 of 2649
# working on buffer 488 of 2649
# working on buffer 489 of 2649
# working on buffer 490 of 2649
# working on buffer 491 of 2649
# working on buffer 492 of 2649
# working on buffer 493 of 2649
# working on buffer 494 of 2649
# working on buffer 495 of 2649
# working on buffer 496 of 2649
# working on buffer 497 of 2649
# working on buffer 498 of 2649
# working on buffer 499 of 2649
# working on buffer 500 of 2649
# working on buffer 501 of 2649
# working on buffer 502 of 2649
# working on buffer 503 of 2649
# working on buffer 504 of 2649
# working on buffer 505 of 2649
# working on buffer 506 of 2649
# working on buffer 507 of 2649
# working on buffer 508 of 2649
# working on buffer 509 of 2649
# working on buffer 510 of 2649
# working on buffer 511 of 2649
# working on buffer 512 of 2649
# working on buffer 513 of 2649
# working on buffer 514 of 2649
# working on buffer 515 of 2649
# working on buffer 516 of 2649
# working on buffer 517 of 2649
# working on buffer 518 of 2649
# working on buffer 519 of 2649
# working on buffer 520 of 2649
# working on buffer 521 of 2649
# working on buffer 522 of 2649
# working on buffer 523 of 2649
# working on buffer 524 of 2649
# working on buffer 525 of 2649
# working on buffer 526 of 2649
# working on buffer 527 of 2649
# working on buffer 528 of 2649
# working on buffer 529 of 2649
# working on buffer 530 of 2649
# working on buffer 531 of 2649
# working on buffer 532 of 2649
# working on buffer 533 of 2649
# working on buffer 534 of 2649
# working on buffer 535 of 2649
# working on buffer 536 of 2649
# working on buffer 537 of 2649
# working on buffer 538 of 2649
# working on buffer 539 of 2649
# working on buffer 540 of 2649
# working on buffer 541 of 2649
# working on buffer 542 of 2649
# working on buffer 543 of 2649
# working on buffer 544 of 2649
# working on buffer 545 of 2649
# working on buffer 546 of 2649
# working on buffer 547 of 2649
# working on buffer 548 of 2649
# working on buffer 549 of 2649
# working on buffer 550 of 2649
# working on buffer 551 of 2649
# working on buffer 552 of 2649
# working on buffer 553 of 2649
# working on buffer 554 of 2649
# working on buffer 555 of 2649
# working on buffer 556 of 2649
# working on buffer 557 of 2649
# working on buffer 558 of 2649
# working on buffer 559 of 2649
# working on buffer 560 of 2649
# working on buffer 561 of 2649
# working on buffer 562 of 2649
# working on buffer 563 of 2649
# working on buffer 564 of 2649
# working on buffer 565 of 2649
# working on buffer 566 of 2649
# working on buffer 567 of 2649
# working on buffer 568 of 2649
# working on buffer 569 of 2649
# working on buffer 570 of 2649
# working on buffer 571 of 2649
# working on buffer 572 of 2649
# working on buffer 573 of 2649
# working on buffer 574 of 2649
# working on buffer 575 of 2649
# working on buffer 576 of 2649
# working on buffer 577 of 2649
# working on buffer 578 of 2649
# working on buffer 579 of 2649
# working on buffer 580 of 2649
# working on buffer 581 of 2649
# working on buffer 582 of 2649
# working on buffer 583 of 2649
# working on buffer 584 of 2649
# working on buffer 585 of 2649
# working on buffer 586 of 2649
# working on buffer 587 of 2649
# working on buffer 588 of 2649
# working on buffer 589 of 2649
# working on buffer 590 of 2649
# working on buffer 591 of 2649
# working on buffer 592 of 2649
# working on buffer 593 of 2649
# working on buffer 594 of 2649
# working on buffer 595 of 2649
# working on buffer 596 of 2649
# working on buffer 597 of 2649
# working on buffer 598 of 2649
# working on buffer 599 of 2649
# working on buffer 600 of 2649
# working on buffer 601 of 2649
# working on buffer 602 of 2649
# working on buffer 603 of 2649
# working on buffer 604 of 2649
# working on buffer 605 of 2649
# working on buffer 606 of 2649
# working on buffer 607 of 2649
# working on buffer 608 of 2649
# working on buffer 609 of 2649
# working on buffer 610 of 2649
# working on buffer 611 of 2649
# working on buffer 612 of 2649
# working on buffer 613 of 2649
# working on buffer 614 of 2649
# working on buffer 615 of 2649
# working on buffer 616 of 2649
# working on buffer 617 of 2649
# working on buffer 618 of 2649
# working on buffer 619 of 2649
# working on buffer 620 of 2649
# working on buffer 621 of 2649
# working on buffer 622 of 2649
# working on buffer 623 of 2649
# working on buffer 624 of 2649
# working on buffer 625 of 2649
# working on buffer 626 of 2649
# working on buffer 627 of 2649
# working on buffer 628 of 2649
# working on buffer 629 of 2649
# working on buffer 630 of 2649
# working on buffer 631 of 2649
# working on buffer 632 of 2649
# working on buffer 633 of 2649
# working on buffer 634 of 2649
# working on buffer 635 of 2649
# working on buffer 636 of 2649
# working on buffer 637 of 2649
# working on buffer 638 of 2649
# working on buffer 639 of 2649
# working on buffer 640 of 2649
# working on buffer 641 of 2649
# working on buffer 642 of 2649
# working on buffer 643 of 2649
# working on buffer 644 of 2649
# working on buffer 645 of 2649
# working on buffer 646 of 2649
# working on buffer 647 of 2649
# working on buffer 648 of 2649
# working on buffer 649 of 2649
# working on buffer 650 of 2649
# working on buffer 651 of 2649
# working on buffer 652 of 2649
# working on buffer 653 of 2649
# working on buffer 654 of 2649
# working on buffer 655 of 2649
# working on buffer 656 of 2649
# working on buffer 657 of 2649
# working on buffer 658 of 2649
# working on buffer 659 of 2649
# working on buffer 660 of 2649
# working on buffer 661 of 2649
# working on buffer 662 of 2649
# working on buffer 663 of 2649
# working on buffer 664 of 2649
# working on buffer 665 of 2649
# working on buffer 666 of 2649
# working on buffer 667 of 2649
# working on buffer 668 of 2649
# working on buffer 669 of 2649
# working on buffer 670 of 2649
# working on buffer 671 of 2649
# working on buffer 672 of 2649
# working on buffer 673 of 2649
# working on buffer 674 of 2649
# working on buffer 675 of 2649
# working on buffer 676 of 2649
# working on buffer 677 of 2649
# working on buffer 678 of 2649
# working on buffer 679 of 2649
# working on buffer 680 of 2649
# working on buffer 681 of 2649
# working on buffer 682 of 2649
# working on buffer 683 of 2649
# working on buffer 684 of 2649
# working on buffer 685 of 2649
# working on buffer 686 of 2649
# working on buffer 687 of 2649
# working on buffer 688 of 2649
# working on buffer 689 of 2649
# working on buffer 690 of 2649
# working on buffer 691 of 2649
# working on buffer 692 of 2649
# working on buffer 693 of 2649
# working on buffer 694 of 2649
# working on buffer 695 of 2649
# working on buffer 696 of 2649
# working on buffer 697 of 2649
# working on buffer 698 of 2649
# working on buffer 699 of 2649
# working on buffer 700 of 2649
# working on buffer 701 of 2649
# working on buffer 702 of 2649
# working on buffer 703 of 2649
# working on buffer 704 of 2649
# working on buffer 705 of 2649
# working on buffer 706 of 2649
# working on buffer 707 of 2649
# working on buffer 708 of 2649
# working on buffer 709 of 2649
# working on buffer 710 of 2649
# working on buffer 711 of 2649
# working on buffer 712 of 2649
# working on buffer 713 of 2649
# working on buffer 714 of 2649
# working on buffer 715 of 2649
# working on buffer 716 of 2649
# working on buffer 717 of 2649
# working on buffer 718 of 2649
# working on buffer 719 of 2649
# working on buffer 720 of 2649
# working on buffer 721 of 2649
# working on buffer 722 of 2649
# working on buffer 723 of 2649
# working on buffer 724 of 2649
# working on buffer 725 of 2649
# working on buffer 726 of 2649
# working on buffer 727 of 2649
# working on buffer 728 of 2649
# working on buffer 729 of 2649
# working on buffer 730 of 2649
# working on buffer 731 of 2649
# working on buffer 732 of 2649
# working on buffer 733 of 2649
# working on buffer 734 of 2649
# working on buffer 735 of 2649
# working on buffer 736 of 2649
# working on buffer 737 of 2649
# working on buffer 738 of 2649
# working on buffer 739 of 2649
# working on buffer 740 of 2649
# working on buffer 741 of 2649
# working on buffer 742 of 2649
# working on buffer 743 of 2649
# working on buffer 744 of 2649
# working on buffer 745 of 2649
# working on buffer 746 of 2649
# working on buffer 747 of 2649
# working on buffer 748 of 2649
# working on buffer 749 of 2649
# working on buffer 750 of 2649
# working on buffer 751 of 2649
# working on buffer 752 of 2649
# working on buffer 753 of 2649
# working on buffer 754 of 2649
# working on buffer 755 of 2649
# working on buffer 756 of 2649
# working on buffer 757 of 2649
# working on buffer 758 of 2649
# working on buffer 759 of 2649
# working on buffer 760 of 2649
# working on buffer 761 of 2649
# working on buffer 762 of 2649
# working on buffer 763 of 2649
# working on buffer 764 of 2649
# working on buffer 765 of 2649
# working on buffer 766 of 2649
# working on buffer 767 of 2649
# working on buffer 768 of 2649
# working on buffer 769 of 2649
# working on buffer 770 of 2649
# working on buffer 771 of 2649
# working on buffer 772 of 2649
# working on buffer 773 of 2649
# working on buffer 774 of 2649
# working on buffer 775 of 2649
# working on buffer 776 of 2649
# working on buffer 777 of 2649
# working on buffer 778 of 2649
# working on buffer 779 of 2649
# working on buffer 780 of 2649
# working on buffer 781 of 2649
# working on buffer 782 of 2649
# working on buffer 783 of 2649
# working on buffer 784 of 2649
# working on buffer 785 of 2649
# working on buffer 786 of 2649
# working on buffer 787 of 2649
# working on buffer 788 of 2649
# working on buffer 789 of 2649
# working on buffer 790 of 2649
# working on buffer 791 of 2649
# working on buffer 792 of 2649
# working on buffer 793 of 2649
# working on buffer 794 of 2649
# working on buffer 795 of 2649
# working on buffer 796 of 2649
# working on buffer 797 of 2649
# working on buffer 798 of 2649
# working on buffer 799 of 2649
# working on buffer 800 of 2649
# working on buffer 801 of 2649
# working on buffer 802 of 2649
# working on buffer 803 of 2649
# working on buffer 804 of 2649
# working on buffer 805 of 2649
# working on buffer 806 of 2649
# working on buffer 807 of 2649
# working on buffer 808 of 2649
# working on buffer 809 of 2649
# working on buffer 810 of 2649
# working on buffer 811 of 2649
# working on buffer 812 of 2649
# working on buffer 813 of 2649
# working on buffer 814 of 2649
# working on buffer 815 of 2649
# working on buffer 816 of 2649
# working on buffer 817 of 2649
# working on buffer 818 of 2649
# working on buffer 819 of 2649
# working on buffer 820 of 2649
# working on buffer 821 of 2649
# working on buffer 822 of 2649
# working on buffer 823 of 2649
# working on buffer 824 of 2649
# working on buffer 825 of 2649
# working on buffer 826 of 2649
# working on buffer 827 of 2649
# working on buffer 828 of 2649
# working on buffer 829 of 2649
# working on buffer 830 of 2649
# working on buffer 831 of 2649
# working on buffer 832 of 2649
# working on buffer 833 of 2649
# working on buffer 834 of 2649
# working on buffer 835 of 2649
# working on buffer 836 of 2649
# working on buffer 837 of 2649
# working on buffer 838 of 2649
# working on buffer 839 of 2649
# working on buffer 840 of 2649
# working on buffer 841 of 2649
# working on buffer 842 of 2649
# working on buffer 843 of 2649
# working on buffer 844 of 2649
# working on buffer 845 of 2649
# working on buffer 846 of 2649
# working on buffer 847 of 2649
# working on buffer 848 of 2649
# working on buffer 849 of 2649
# working on buffer 850 of 2649
# working on buffer 851 of 2649
# working on buffer 852 of 2649
# working on buffer 853 of 2649
# working on buffer 854 of 2649
# working on buffer 855 of 2649
# working on buffer 856 of 2649
# working on buffer 857 of 2649
# working on buffer 858 of 2649
# working on buffer 859 of 2649
# working on buffer 860 of 2649
# working on buffer 861 of 2649
# working on buffer 862 of 2649
# working on buffer 863 of 2649
# working on buffer 864 of 2649
# working on buffer 865 of 2649
# working on buffer 866 of 2649
# working on buffer 867 of 2649
# working on buffer 868 of 2649
# working on buffer 869 of 2649
# working on buffer 870 of 2649
# working on buffer 871 of 2649
# working on buffer 872 of 2649
# working on buffer 873 of 2649
# working on buffer 874 of 2649
# working on buffer 875 of 2649
# working on buffer 876 of 2649
# working on buffer 877 of 2649
# working on buffer 878 of 2649
# working on buffer 879 of 2649
# working on buffer 880 of 2649
# working on buffer 881 of 2649
# working on buffer 882 of 2649
# working on buffer 883 of 2649
# working on buffer 884 of 2649
# working on buffer 885 of 2649
# working on buffer 886 of 2649
# working on buffer 887 of 2649
# working on buffer 888 of 2649
# working on buffer 889 of 2649
# working on buffer 890 of 2649
# working on buffer 891 of 2649
# working on buffer 892 of 2649
# working on buffer 893 of 2649
# working on buffer 894 of 2649
# working on buffer 895 of 2649
# working on buffer 896 of 2649
# working on buffer 897 of 2649
# working on buffer 898 of 2649
# working on buffer 899 of 2649
# working on buffer 900 of 2649
# working on buffer 901 of 2649
# working on buffer 902 of 2649
# working on buffer 903 of 2649
# working on buffer 904 of 2649
# working on buffer 905 of 2649
# working on buffer 906 of 2649
# working on buffer 907 of 2649
# working on buffer 908 of 2649
# working on buffer 909 of 2649
# working on buffer 910 of 2649
# working on buffer 911 of 2649
# working on buffer 912 of 2649
# working on buffer 913 of 2649
# working on buffer 914 of 2649
# working on buffer 915 of 2649
# working on buffer 916 of 2649
# working on buffer 917 of 2649
# working on buffer 918 of 2649
# working on buffer 919 of 2649
# working on buffer 920 of 2649
# working on buffer 921 of 2649
# working on buffer 922 of 2649
# working on buffer 923 of 2649
# working on buffer 924 of 2649
# working on buffer 925 of 2649
# working on buffer 926 of 2649
# working on buffer 927 of 2649
# working on buffer 928 of 2649
# working on buffer 929 of 2649
# working on buffer 930 of 2649
# working on buffer 931 of 2649
# working on buffer 932 of 2649
# working on buffer 933 of 2649
# working on buffer 934 of 2649
# working on buffer 935 of 2649
# working on buffer 936 of 2649
# working on buffer 937 of 2649
# working on buffer 938 of 2649
# working on buffer 939 of 2649
# working on buffer 940 of 2649
# working on buffer 941 of 2649
# working on buffer 942 of 2649
# working on buffer 943 of 2649
# working on buffer 944 of 2649
# working on buffer 945 of 2649
# working on buffer 946 of 2649
# working on buffer 947 of 2649
# working on buffer 948 of 2649
# working on buffer 949 of 2649
# working on buffer 950 of 2649
# working on buffer 951 of 2649
# working on buffer 952 of 2649
# working on buffer 953 of 2649
# working on buffer 954 of 2649
# working on buffer 955 of 2649
# working on buffer 956 of 2649
# working on buffer 957 of 2649
# working on buffer 958 of 2649
# working on buffer 959 of 2649
# working on buffer 960 of 2649
# working on buffer 961 of 2649
# working on buffer 962 of 2649
# working on buffer 963 of 2649
# working on buffer 964 of 2649
# working on buffer 965 of 2649
# working on buffer 966 of 2649
# working on buffer 967 of 2649
# working on buffer 968 of 2649
# working on buffer 969 of 2649
# working on buffer 970 of 2649
# working on buffer 971 of 2649
# working on buffer 972 of 2649
# working on buffer 973 of 2649
# working on buffer 974 of 2649
# working on buffer 975 of 2649
# working on buffer 976 of 2649
# working on buffer 977 of 2649
# working on buffer 978 of 2649
# working on buffer 979 of 2649
# working on buffer 980 of 2649
# working on buffer 981 of 2649
# working on buffer 982 of 2649
# working on buffer 983 of 2649
# working on buffer 984 of 2649
# working on buffer 985 of 2649
# working on buffer 986 of 2649
# working on buffer 987 of 2649
# working on buffer 988 of 2649
# working on buffer 989 of 2649
# working on buffer 990 of 2649
# working on buffer 991 of 2649
# working on buffer 992 of 2649
# working on buffer 993 of 2649
# working on buffer 994 of 2649
# working on buffer 995 of 2649
# working on buffer 996 of 2649
# working on buffer 997 of 2649
# working on buffer 998 of 2649
# working on buffer 999 of 2649
# working on buffer 1000 of 2649
# working on buffer 1001 of 2649
# working on buffer 1002 of 2649
# working on buffer 1003 of 2649
# working on buffer 1004 of 2649
# working on buffer 1005 of 2649
# working on buffer 1006 of 2649
# working on buffer 1007 of 2649
# working on buffer 1008 of 2649
# working on buffer 1009 of 2649
# working on buffer 1010 of 2649
# working on buffer 1011 of 2649
# working on buffer 1012 of 2649
# working on buffer 1013 of 2649
# working on buffer 1014 of 2649
# working on buffer 1015 of 2649
# working on buffer 1016 of 2649
# working on buffer 1017 of 2649
# working on buffer 1018 of 2649
# working on buffer 1019 of 2649
# working on buffer 1020 of 2649
# working on buffer 1021 of 2649
# working on buffer 1022 of 2649
# working on buffer 1023 of 2649
# working on buffer 1024 of 2649
# working on buffer 1025 of 2649
# working on buffer 1026 of 2649
# working on buffer 1027 of 2649
# working on buffer 1028 of 2649
# working on buffer 1029 of 2649
# working on buffer 1030 of 2649
# working on buffer 1031 of 2649
# working on buffer 1032 of 2649
# working on buffer 1033 of 2649
# working on buffer 1034 of 2649
# working on buffer 1035 of 2649
# working on buffer 1036 of 2649
# working on buffer 1037 of 2649
# working on buffer 1038 of 2649
# working on buffer 1039 of 2649
# working on buffer 1040 of 2649
# working on buffer 1041 of 2649
# working on buffer 1042 of 2649
# working on buffer 1043 of 2649
# working on buffer 1044 of 2649
# working on buffer 1045 of 2649
# working on buffer 1046 of 2649
# working on buffer 1047 of 2649
# working on buffer 1048 of 2649
# working on buffer 1049 of 2649
# working on buffer 1050 of 2649
# working on buffer 1051 of 2649
# working on buffer 1052 of 2649
# working on buffer 1053 of 2649
# working on buffer 1054 of 2649
# working on buffer 1055 of 2649
# working on buffer 1056 of 2649
# working on buffer 1057 of 2649
# working on buffer 1058 of 2649
# working on buffer 1059 of 2649
# working on buffer 1060 of 2649
# working on buffer 1061 of 2649
# working on buffer 1062 of 2649
# working on buffer 1063 of 2649
# working on buffer 1064 of 2649
# working on buffer 1065 of 2649
# working on buffer 1066 of 2649
# working on buffer 1067 of 2649
# working on buffer 1068 of 2649
# working on buffer 1069 of 2649
# working on buffer 1070 of 2649
# working on buffer 1071 of 2649
# working on buffer 1072 of 2649
# working on buffer 1073 of 2649
# working on buffer 1074 of 2649
# working on buffer 1075 of 2649
# working on buffer 1076 of 2649
# working on buffer 1077 of 2649
# working on buffer 1078 of 2649
# working on buffer 1079 of 2649
# working on buffer 1080 of 2649
# working on buffer 1081 of 2649
# working on buffer 1082 of 2649
# working on buffer 1083 of 2649
# working on buffer 1084 of 2649
# working on buffer 1085 of 2649
# working on buffer 1086 of 2649
# working on buffer 1087 of 2649
# working on buffer 1088 of 2649
# working on buffer 1089 of 2649
# working on buffer 1090 of 2649
# working on buffer 1091 of 2649
# working on buffer 1092 of 2649
# working on buffer 1093 of 2649
# working on buffer 1094 of 2649
# working on buffer 1095 of 2649
# working on buffer 1096 of 2649
# working on buffer 1097 of 2649
# working on buffer 1098 of 2649
# working on buffer 1099 of 2649
# working on buffer 1100 of 2649
# working on buffer 1101 of 2649
# working on buffer 1102 of 2649
# working on buffer 1103 of 2649
# working on buffer 1104 of 2649
# working on buffer 1105 of 2649
# working on buffer 1106 of 2649
# working on buffer 1107 of 2649
# working on buffer 1108 of 2649
# working on buffer 1109 of 2649
# working on buffer 1110 of 2649
# working on buffer 1111 of 2649
# working on buffer 1112 of 2649
# working on buffer 1113 of 2649
# working on buffer 1114 of 2649
# working on buffer 1115 of 2649
# working on buffer 1116 of 2649
# working on buffer 1117 of 2649
# working on buffer 1118 of 2649
# working on buffer 1119 of 2649
# working on buffer 1120 of 2649
# working on buffer 1121 of 2649
# working on buffer 1122 of 2649
# working on buffer 1123 of 2649
# working on buffer 1124 of 2649
# working on buffer 1125 of 2649
# working on buffer 1126 of 2649
# working on buffer 1127 of 2649
# working on buffer 1128 of 2649
# working on buffer 1129 of 2649
# working on buffer 1130 of 2649
# working on buffer 1131 of 2649
# working on buffer 1132 of 2649
# working on buffer 1133 of 2649
# working on buffer 1134 of 2649
# working on buffer 1135 of 2649
# working on buffer 1136 of 2649
# working on buffer 1137 of 2649
# working on buffer 1138 of 2649
# working on buffer 1139 of 2649
# working on buffer 1140 of 2649
# working on buffer 1141 of 2649
# working on buffer 1142 of 2649
# working on buffer 1143 of 2649
# working on buffer 1144 of 2649
# working on buffer 1145 of 2649
# working on buffer 1146 of 2649
# working on buffer 1147 of 2649
# working on buffer 1148 of 2649
# working on buffer 1149 of 2649
# working on buffer 1150 of 2649
# working on buffer 1151 of 2649
# working on buffer 1152 of 2649
# working on buffer 1153 of 2649
# working on buffer 1154 of 2649
# working on buffer 1155 of 2649
# working on buffer 1156 of 2649
# working on buffer 1157 of 2649
# working on buffer 1158 of 2649
# working on buffer 1159 of 2649
# working on buffer 1160 of 2649
# working on buffer 1161 of 2649
# working on buffer 1162 of 2649
# working on buffer 1163 of 2649
# working on buffer 1164 of 2649
# working on buffer 1165 of 2649
# working on buffer 1166 of 2649
# working on buffer 1167 of 2649
# working on buffer 1168 of 2649
# working on buffer 1169 of 2649
# working on buffer 1170 of 2649
# working on buffer 1171 of 2649
# working on buffer 1172 of 2649
# working on buffer 1173 of 2649
# working on buffer 1174 of 2649
# working on buffer 1175 of 2649
# working on buffer 1176 of 2649
# working on buffer 1177 of 2649
# working on buffer 1178 of 2649
# working on buffer 1179 of 2649
# working on buffer 1180 of 2649
# working on buffer 1181 of 2649
# working on buffer 1182 of 2649
# working on buffer 1183 of 2649
# working on buffer 1184 of 2649
# working on buffer 1185 of 2649
# working on buffer 1186 of 2649
# working on buffer 1187 of 2649
# working on buffer 1188 of 2649
# working on buffer 1189 of 2649
# working on buffer 1190 of 2649
# working on buffer 1191 of 2649
# working on buffer 1192 of 2649
# working on buffer 1193 of 2649
# working on buffer 1194 of 2649
# working on buffer 1195 of 2649
# working on buffer 1196 of 2649
# working on buffer 1197 of 2649
# working on buffer 1198 of 2649
# working on buffer 1199 of 2649
# working on buffer 1200 of 2649
# working on buffer 1201 of 2649
# working on buffer 1202 of 2649
# working on buffer 1203 of 2649
# working on buffer 1204 of 2649
# working on buffer 1205 of 2649
# working on buffer 1206 of 2649
# working on buffer 1207 of 2649
# working on buffer 1208 of 2649
# working on buffer 1209 of 2649
# working on buffer 1210 of 2649
# working on buffer 1211 of 2649
# working on buffer 1212 of 2649
# working on buffer 1213 of 2649
# working on buffer 1214 of 2649
# working on buffer 1215 of 2649
# working on buffer 1216 of 2649
# working on buffer 1217 of 2649
# working on buffer 1218 of 2649
# working on buffer 1219 of 2649
# working on buffer 1220 of 2649
# working on buffer 1221 of 2649
# working on buffer 1222 of 2649
# working on buffer 1223 of 2649
# working on buffer 1224 of 2649
# working on buffer 1225 of 2649
# working on buffer 1226 of 2649
# working on buffer 1227 of 2649
# working on buffer 1228 of 2649
# working on buffer 1229 of 2649
# working on buffer 1230 of 2649
# working on buffer 1231 of 2649
# working on buffer 1232 of 2649
# working on buffer 1233 of 2649
# working on buffer 1234 of 2649
# working on buffer 1235 of 2649
# working on buffer 1236 of 2649
# working on buffer 1237 of 2649
# working on buffer 1238 of 2649
# working on buffer 1239 of 2649
# working on buffer 1240 of 2649
# working on buffer 1241 of 2649
# working on buffer 1242 of 2649
# working on buffer 1243 of 2649
# working on buffer 1244 of 2649
# working on buffer 1245 of 2649
# working on buffer 1246 of 2649
# working on buffer 1247 of 2649
# working on buffer 1248 of 2649
# working on buffer 1249 of 2649
# working on buffer 1250 of 2649
# working on buffer 1251 of 2649
# working on buffer 1252 of 2649
# working on buffer 1253 of 2649
# working on buffer 1254 of 2649
# working on buffer 1255 of 2649
# working on buffer 1256 of 2649
# working on buffer 1257 of 2649
# working on buffer 1258 of 2649
# working on buffer 1259 of 2649
# working on buffer 1260 of 2649
# working on buffer 1261 of 2649
# working on buffer 1262 of 2649
# working on buffer 1263 of 2649
# working on buffer 1264 of 2649
# working on buffer 1265 of 2649
# working on buffer 1266 of 2649
# working on buffer 1267 of 2649
# working on buffer 1268 of 2649
# working on buffer 1269 of 2649
# working on buffer 1270 of 2649
# working on buffer 1271 of 2649
# working on buffer 1272 of 2649
# working on buffer 1273 of 2649
# working on buffer 1274 of 2649
# working on buffer 1275 of 2649
# working on buffer 1276 of 2649
# working on buffer 1277 of 2649
# working on buffer 1278 of 2649
# working on buffer 1279 of 2649
# working on buffer 1280 of 2649
# working on buffer 1281 of 2649
# working on buffer 1282 of 2649
# working on buffer 1283 of 2649
# working on buffer 1284 of 2649
# working on buffer 1285 of 2649
# working on buffer 1286 of 2649
# working on buffer 1287 of 2649
# working on buffer 1288 of 2649
# working on buffer 1289 of 2649
# working on buffer 1290 of 2649
# working on buffer 1291 of 2649
# working on buffer 1292 of 2649
# working on buffer 1293 of 2649
# working on buffer 1294 of 2649
# working on buffer 1295 of 2649
# working on buffer 1296 of 2649
# working on buffer 1297 of 2649
# working on buffer 1298 of 2649
# working on buffer 1299 of 2649
# working on buffer 1300 of 2649
# working on buffer 1301 of 2649
# working on buffer 1302 of 2649
# working on buffer 1303 of 2649
# working on buffer 1304 of 2649
# working on buffer 1305 of 2649
# working on buffer 1306 of 2649
# working on buffer 1307 of 2649
# working on buffer 1308 of 2649
# working on buffer 1309 of 2649
# working on buffer 1310 of 2649
# working on buffer 1311 of 2649
# working on buffer 1312 of 2649
# working on buffer 1313 of 2649
# working on buffer 1314 of 2649
# working on buffer 1315 of 2649
# working on buffer 1316 of 2649
# working on buffer 1317 of 2649
# working on buffer 1318 of 2649
# working on buffer 1319 of 2649
# working on buffer 1320 of 2649
# working on buffer 1321 of 2649
# working on buffer 1322 of 2649
# working on buffer 1323 of 2649
# working on buffer 1324 of 2649
# working on buffer 1325 of 2649
# working on buffer 1326 of 2649
# working on buffer 1327 of 2649
# working on buffer 1328 of 2649
# working on buffer 1329 of 2649
# working on buffer 1330 of 2649
# working on buffer 1331 of 2649
# working on buffer 1332 of 2649
# working on buffer 1333 of 2649
# working on buffer 1334 of 2649
# working on buffer 1335 of 2649
# working on buffer 1336 of 2649
# working on buffer 1337 of 2649
# working on buffer 1338 of 2649
# working on buffer 1339 of 2649
# working on buffer 1340 of 2649
# working on buffer 1341 of 2649
# working on buffer 1342 of 2649
# working on buffer 1343 of 2649
# working on buffer 1344 of 2649
# working on buffer 1345 of 2649
# working on buffer 1346 of 2649
# working on buffer 1347 of 2649
# working on buffer 1348 of 2649
# working on buffer 1349 of 2649
# working on buffer 1350 of 2649
# working on buffer 1351 of 2649
# working on buffer 1352 of 2649
# working on buffer 1353 of 2649
# working on buffer 1354 of 2649
# working on buffer 1355 of 2649
# working on buffer 1356 of 2649
# working on buffer 1357 of 2649
# working on buffer 1358 of 2649
# working on buffer 1359 of 2649
# working on buffer 1360 of 2649
# working on buffer 1361 of 2649
# working on buffer 1362 of 2649
# working on buffer 1363 of 2649
# working on buffer 1364 of 2649
# working on buffer 1365 of 2649
# working on buffer 1366 of 2649
# working on buffer 1367 of 2649
# working on buffer 1368 of 2649
# working on buffer 1369 of 2649
# working on buffer 1370 of 2649
# working on buffer 1371 of 2649
# working on buffer 1372 of 2649
# working on buffer 1373 of 2649
# working on buffer 1374 of 2649
# working on buffer 1375 of 2649
# working on buffer 1376 of 2649
# working on buffer 1377 of 2649
# working on buffer 1378 of 2649
# working on buffer 1379 of 2649
# working on buffer 1380 of 2649
# working on buffer 1381 of 2649
# working on buffer 1382 of 2649
# working on buffer 1383 of 2649
# working on buffer 1384 of 2649
# working on buffer 1385 of 2649
# working on buffer 1386 of 2649
# working on buffer 1387 of 2649
# working on buffer 1388 of 2649
# working on buffer 1389 of 2649
# working on buffer 1390 of 2649
# working on buffer 1391 of 2649
# working on buffer 1392 of 2649
# working on buffer 1393 of 2649
# working on buffer 1394 of 2649
# working on buffer 1395 of 2649
# working on buffer 1396 of 2649
# working on buffer 1397 of 2649
# working on buffer 1398 of 2649
# working on buffer 1399 of 2649
# working on buffer 1400 of 2649
# working on buffer 1401 of 2649
# working on buffer 1402 of 2649
# working on buffer 1403 of 2649
# working on buffer 1404 of 2649
# working on buffer 1405 of 2649
# working on buffer 1406 of 2649
# working on buffer 1407 of 2649
# working on buffer 1408 of 2649
# working on buffer 1409 of 2649
# working on buffer 1410 of 2649
# working on buffer 1411 of 2649
# working on buffer 1412 of 2649
# working on buffer 1413 of 2649
# working on buffer 1414 of 2649
# working on buffer 1415 of 2649
# working on buffer 1416 of 2649
# working on buffer 1417 of 2649
# working on buffer 1418 of 2649
# working on buffer 1419 of 2649
# working on buffer 1420 of 2649
# working on buffer 1421 of 2649
# working on buffer 1422 of 2649
# working on buffer 1423 of 2649
# working on buffer 1424 of 2649
# working on buffer 1425 of 2649
# working on buffer 1426 of 2649
# working on buffer 1427 of 2649
# working on buffer 1428 of 2649
# working on buffer 1429 of 2649
# working on buffer 1430 of 2649
# working on buffer 1431 of 2649
# working on buffer 1432 of 2649
# working on buffer 1433 of 2649
# working on buffer 1434 of 2649
# working on buffer 1435 of 2649
# working on buffer 1436 of 2649
# working on buffer 1437 of 2649
# working on buffer 1438 of 2649
# working on buffer 1439 of 2649
# working on buffer 1440 of 2649
# working on buffer 1441 of 2649
# working on buffer 1442 of 2649
# working on buffer 1443 of 2649
# working on buffer 1444 of 2649
# working on buffer 1445 of 2649
# working on buffer 1446 of 2649
# working on buffer 1447 of 2649
# working on buffer 1448 of 2649
# working on buffer 1449 of 2649
# working on buffer 1450 of 2649
# working on buffer 1451 of 2649
# working on buffer 1452 of 2649
# working on buffer 1453 of 2649
# working on buffer 1454 of 2649
# working on buffer 1455 of 2649
# working on buffer 1456 of 2649
# working on buffer 1457 of 2649
# working on buffer 1458 of 2649
# working on buffer 1459 of 2649
# working on buffer 1460 of 2649
# working on buffer 1461 of 2649
# working on buffer 1462 of 2649
# working on buffer 1463 of 2649
# working on buffer 1464 of 2649
# working on buffer 1465 of 2649
# working on buffer 1466 of 2649
# working on buffer 1467 of 2649
# working on buffer 1468 of 2649
# working on buffer 1469 of 2649
# working on buffer 1470 of 2649
# working on buffer 1471 of 2649
# working on buffer 1472 of 2649
# working on buffer 1473 of 2649
# working on buffer 1474 of 2649
# working on buffer 1475 of 2649
# working on buffer 1476 of 2649
# working on buffer 1477 of 2649
# working on buffer 1478 of 2649
# working on buffer 1479 of 2649
# working on buffer 1480 of 2649
# working on buffer 1481 of 2649
# working on buffer 1482 of 2649
# working on buffer 1483 of 2649
# working on buffer 1484 of 2649
# working on buffer 1485 of 2649
# working on buffer 1486 of 2649
# working on buffer 1487 of 2649
# working on buffer 1488 of 2649
# working on buffer 1489 of 2649
# working on buffer 1490 of 2649
# working on buffer 1491 of 2649
# working on buffer 1492 of 2649
# working on buffer 1493 of 2649
# working on buffer 1494 of 2649
# working on buffer 1495 of 2649
# working on buffer 1496 of 2649
# working on buffer 1497 of 2649
# working on buffer 1498 of 2649
# working on buffer 1499 of 2649
# working on buffer 1500 of 2649
# working on buffer 1501 of 2649
# working on buffer 1502 of 2649
# working on buffer 1503 of 2649
# working on buffer 1504 of 2649
# working on buffer 1505 of 2649
# working on buffer 1506 of 2649
# working on buffer 1507 of 2649
# working on buffer 1508 of 2649
# working on buffer 1509 of 2649
# working on buffer 1510 of 2649
# working on buffer 1511 of 2649
# working on buffer 1512 of 2649
# working on buffer 1513 of 2649
# working on buffer 1514 of 2649
# working on buffer 1515 of 2649
# working on buffer 1516 of 2649
# working on buffer 1517 of 2649
# working on buffer 1518 of 2649
# working on buffer 1519 of 2649
# working on buffer 1520 of 2649
# working on buffer 1521 of 2649
# working on buffer 1522 of 2649
# working on buffer 1523 of 2649
# working on buffer 1524 of 2649
# working on buffer 1525 of 2649
# working on buffer 1526 of 2649
# working on buffer 1527 of 2649
# working on buffer 1528 of 2649
# working on buffer 1529 of 2649
# working on buffer 1530 of 2649
# working on buffer 1531 of 2649
# working on buffer 1532 of 2649
# working on buffer 1533 of 2649
# working on buffer 1534 of 2649
# working on buffer 1535 of 2649
# working on buffer 1536 of 2649
# working on buffer 1537 of 2649
# working on buffer 1538 of 2649
# working on buffer 1539 of 2649
# working on buffer 1540 of 2649
# working on buffer 1541 of 2649
# working on buffer 1542 of 2649
# working on buffer 1543 of 2649
# working on buffer 1544 of 2649
# working on buffer 1545 of 2649
# working on buffer 1546 of 2649
# working on buffer 1547 of 2649
# working on buffer 1548 of 2649
# working on buffer 1549 of 2649
# working on buffer 1550 of 2649
# working on buffer 1551 of 2649
# working on buffer 1552 of 2649
# working on buffer 1553 of 2649
# working on buffer 1554 of 2649
# working on buffer 1555 of 2649
# working on buffer 1556 of 2649
# working on buffer 1557 of 2649
# working on buffer 1558 of 2649
# working on buffer 1559 of 2649
# working on buffer 1560 of 2649
# working on buffer 1561 of 2649
# working on buffer 1562 of 2649
# working on buffer 1563 of 2649
# working on buffer 1564 of 2649
# working on buffer 1565 of 2649
# working on buffer 1566 of 2649
# working on buffer 1567 of 2649
# working on buffer 1568 of 2649
# working on buffer 1569 of 2649
# working on buffer 1570 of 2649
# working on buffer 1571 of 2649
# working on buffer 1572 of 2649
# working on buffer 1573 of 2649
# working on buffer 1574 of 2649
# working on buffer 1575 of 2649
# working on buffer 1576 of 2649
# working on buffer 1577 of 2649
# working on buffer 1578 of 2649
# working on buffer 1579 of 2649
# working on buffer 1580 of 2649
# working on buffer 1581 of 2649
# working on buffer 1582 of 2649
# working on buffer 1583 of 2649
# ...
# working on buffer 2140 of 2649
# working on buffer 2141 of 2649
# working on buffer 2142 of 2649
# working on buffer 2143 of 2649
# working on buffer 2144 of 2649
# working on buffer 2145 of 2649
# working on buffer 2146 of 2649
# working on buffer 2147 of 2649
# working on buffer 2148 of 2649
# working on buffer 2149 of 2649
# working on buffer 2150 of 2649
# working on buffer 2151 of 2649
# working on buffer 2152 of 2649
# working on buffer 2153 of 2649
# working on buffer 2154 of 2649
# working on buffer 2155 of 2649
# working on buffer 2156 of 2649
# working on buffer 2157 of 2649
# working on buffer 2158 of 2649
# working on buffer 2159 of 2649
# working on buffer 2160 of 2649
# working on buffer 2161 of 2649
# working on buffer 2162 of 2649
# working on buffer 2163 of 2649
# working on buffer 2164 of 2649
# working on buffer 2165 of 2649
# working on buffer 2166 of 2649
# working on buffer 2167 of 2649
# working on buffer 2168 of 2649
# working on buffer 2169 of 2649
# working on buffer 2170 of 2649
# working on buffer 2171 of 2649
# working on buffer 2172 of 2649
# working on buffer 2173 of 2649
# working on buffer 2174 of 2649
# working on buffer 2175 of 2649
# working on buffer 2176 of 2649
# working on buffer 2177 of 2649
# working on buffer 2178 of 2649
# working on buffer 2179 of 2649
# working on buffer 2180 of 2649
# working on buffer 2181 of 2649
# working on buffer 2182 of 2649
# working on buffer 2183 of 2649
# working on buffer 2184 of 2649
# working on buffer 2185 of 2649
# working on buffer 2186 of 2649
# working on buffer 2187 of 2649
# working on buffer 2188 of 2649
# working on buffer 2189 of 2649
# working on buffer 2190 of 2649
# working on buffer 2191 of 2649
# working on buffer 2192 of 2649
# working on buffer 2193 of 2649
# working on buffer 2194 of 2649
# working on buffer 2195 of 2649
# working on buffer 2196 of 2649
# working on buffer 2197 of 2649
# working on buffer 2198 of 2649
# working on buffer 2199 of 2649
# working on buffer 2200 of 2649
# working on buffer 2201 of 2649
# working on buffer 2202 of 2649
# working on buffer 2203 of 2649
# working on buffer 2204 of 2649
# working on buffer 2205 of 2649
# working on buffer 2206 of 2649
# working on buffer 2207 of 2649
# working on buffer 2208 of 2649
# working on buffer 2209 of 2649
# working on buffer 2210 of 2649
# working on buffer 2211 of 2649
# working on buffer 2212 of 2649
# working on buffer 2213 of 2649
# working on buffer 2214 of 2649
# working on buffer 2215 of 2649
# working on buffer 2216 of 2649
# working on buffer 2217 of 2649
# working on buffer 2218 of 2649
# working on buffer 2219 of 2649
# working on buffer 2220 of 2649
# working on buffer 2221 of 2649
# working on buffer 2222 of 2649
# working on buffer 2223 of 2649
# working on buffer 2224 of 2649
# working on buffer 2225 of 2649
# working on buffer 2226 of 2649
# working on buffer 2227 of 2649
# working on buffer 2228 of 2649
# working on buffer 2229 of 2649
# working on buffer 2230 of 2649
# working on buffer 2231 of 2649
# working on buffer 2232 of 2649
# working on buffer 2233 of 2649
# working on buffer 2234 of 2649
# working on buffer 2235 of 2649
# working on buffer 2236 of 2649
# working on buffer 2237 of 2649
# working on buffer 2238 of 2649
# working on buffer 2239 of 2649
# working on buffer 2240 of 2649
# working on buffer 2241 of 2649
# working on buffer 2242 of 2649
# working on buffer 2243 of 2649
# working on buffer 2244 of 2649
# working on buffer 2245 of 2649
# working on buffer 2246 of 2649
# working on buffer 2247 of 2649
# working on buffer 2248 of 2649
# working on buffer 2249 of 2649
# working on buffer 2250 of 2649
# working on buffer 2251 of 2649
# working on buffer 2252 of 2649
# working on buffer 2253 of 2649
# working on buffer 2254 of 2649
# working on buffer 2255 of 2649
# working on buffer 2256 of 2649
# working on buffer 2257 of 2649
# working on buffer 2258 of 2649
# working on buffer 2259 of 2649
# working on buffer 2260 of 2649
# working on buffer 2261 of 2649
# working on buffer 2262 of 2649
# working on buffer 2263 of 2649
# working on buffer 2264 of 2649
# working on buffer 2265 of 2649
# working on buffer 2266 of 2649
# working on buffer 2267 of 2649
# working on buffer 2268 of 2649
# working on buffer 2269 of 2649
# working on buffer 2270 of 2649
# working on buffer 2271 of 2649
# working on buffer 2272 of 2649
# working on buffer 2273 of 2649
# working on buffer 2274 of 2649
# working on buffer 2275 of 2649
# working on buffer 2276 of 2649
# working on buffer 2277 of 2649
# working on buffer 2278 of 2649
# working on buffer 2279 of 2649
# working on buffer 2280 of 2649
# working on buffer 2281 of 2649
# working on buffer 2282 of 2649
# working on buffer 2283 of 2649
# working on buffer 2284 of 2649
# working on buffer 2285 of 2649
# working on buffer 2286 of 2649
# working on buffer 2287 of 2649
# working on buffer 2288 of 2649
# working on buffer 2289 of 2649
# working on buffer 2290 of 2649
# working on buffer 2291 of 2649
# working on buffer 2292 of 2649
# working on buffer 2293 of 2649
# working on buffer 2294 of 2649
# working on buffer 2295 of 2649
# working on buffer 2296 of 2649
# working on buffer 2297 of 2649
# working on buffer 2298 of 2649
# working on buffer 2299 of 2649
# working on buffer 2300 of 2649
# working on buffer 2301 of 2649
# working on buffer 2302 of 2649
# working on buffer 2303 of 2649
# working on buffer 2304 of 2649
# working on buffer 2305 of 2649
# working on buffer 2306 of 2649
# working on buffer 2307 of 2649
# working on buffer 2308 of 2649
# working on buffer 2309 of 2649
# working on buffer 2310 of 2649
# working on buffer 2311 of 2649
# working on buffer 2312 of 2649
# working on buffer 2313 of 2649
# working on buffer 2314 of 2649
# working on buffer 2315 of 2649
# working on buffer 2316 of 2649
# working on buffer 2317 of 2649
# working on buffer 2318 of 2649
# working on buffer 2319 of 2649
# working on buffer 2320 of 2649
# working on buffer 2321 of 2649
# working on buffer 2322 of 2649
# working on buffer 2323 of 2649
# working on buffer 2324 of 2649
# working on buffer 2325 of 2649
# working on buffer 2326 of 2649
# working on buffer 2327 of 2649
# working on buffer 2328 of 2649
# working on buffer 2329 of 2649
# working on buffer 2330 of 2649
# working on buffer 2331 of 2649
# working on buffer 2332 of 2649
# working on buffer 2333 of 2649
# working on buffer 2334 of 2649
# working on buffer 2335 of 2649
# working on buffer 2336 of 2649
# working on buffer 2337 of 2649
# working on buffer 2338 of 2649
# working on buffer 2339 of 2649
# working on buffer 2340 of 2649
# working on buffer 2341 of 2649
# working on buffer 2342 of 2649
# working on buffer 2343 of 2649
# working on buffer 2344 of 2649
# working on buffer 2345 of 2649
# working on buffer 2346 of 2649
# working on buffer 2347 of 2649
# working on buffer 2348 of 2649
# working on buffer 2349 of 2649
# working on buffer 2350 of 2649
# working on buffer 2351 of 2649
# working on buffer 2352 of 2649
# working on buffer 2353 of 2649
# working on buffer 2354 of 2649
# working on buffer 2355 of 2649
# working on buffer 2356 of 2649
# working on buffer 2357 of 2649
# working on buffer 2358 of 2649
# working on buffer 2359 of 2649
# working on buffer 2360 of 2649
# working on buffer 2361 of 2649
# working on buffer 2362 of 2649
# working on buffer 2363 of 2649
# working on buffer 2364 of 2649
# working on buffer 2365 of 2649
# working on buffer 2366 of 2649
# working on buffer 2367 of 2649
# working on buffer 2368 of 2649
# working on buffer 2369 of 2649
# working on buffer 2370 of 2649
# working on buffer 2371 of 2649
# working on buffer 2372 of 2649
# working on buffer 2373 of 2649
# working on buffer 2374 of 2649
# working on buffer 2375 of 2649
# working on buffer 2376 of 2649
# working on buffer 2377 of 2649
# working on buffer 2378 of 2649
# working on buffer 2379 of 2649
# working on buffer 2380 of 2649
# working on buffer 2381 of 2649
# working on buffer 2382 of 2649
# working on buffer 2383 of 2649
# working on buffer 2384 of 2649
# working on buffer 2385 of 2649
# working on buffer 2386 of 2649
# working on buffer 2387 of 2649
# working on buffer 2388 of 2649
# working on buffer 2389 of 2649
# working on buffer 2390 of 2649
# working on buffer 2391 of 2649
# working on buffer 2392 of 2649
# working on buffer 2393 of 2649
# working on buffer 2394 of 2649
# working on buffer 2395 of 2649
# working on buffer 2396 of 2649
# working on buffer 2397 of 2649
# working on buffer 2398 of 2649
# working on buffer 2399 of 2649
# working on buffer 2400 of 2649
# working on buffer 2401 of 2649
# working on buffer 2402 of 2649
# working on buffer 2403 of 2649
# working on buffer 2404 of 2649
# working on buffer 2405 of 2649
# working on buffer 2406 of 2649
# working on buffer 2407 of 2649
# working on buffer 2408 of 2649
# working on buffer 2409 of 2649
# working on buffer 2410 of 2649
# working on buffer 2411 of 2649
# working on buffer 2412 of 2649
# working on buffer 2413 of 2649
# working on buffer 2414 of 2649
# working on buffer 2415 of 2649
# working on buffer 2416 of 2649
# working on buffer 2417 of 2649
# working on buffer 2418 of 2649
# working on buffer 2419 of 2649
# working on buffer 2420 of 2649
# working on buffer 2421 of 2649
# working on buffer 2422 of 2649
# working on buffer 2423 of 2649
# working on buffer 2424 of 2649
# working on buffer 2425 of 2649
# working on buffer 2426 of 2649
# working on buffer 2427 of 2649
# working on buffer 2428 of 2649
# working on buffer 2429 of 2649
# working on buffer 2430 of 2649
# working on buffer 2431 of 2649
# working on buffer 2432 of 2649
# working on buffer 2433 of 2649
# working on buffer 2434 of 2649
# working on buffer 2435 of 2649
# working on buffer 2436 of 2649
# working on buffer 2437 of 2649
# working on buffer 2438 of 2649
# working on buffer 2439 of 2649
# working on buffer 2440 of 2649
# working on buffer 2441 of 2649
# working on buffer 2442 of 2649
# working on buffer 2443 of 2649
# working on buffer 2444 of 2649
# working on buffer 2445 of 2649
# working on buffer 2446 of 2649
# working on buffer 2447 of 2649
# working on buffer 2448 of 2649
# working on buffer 2449 of 2649
# working on buffer 2450 of 2649
# working on buffer 2451 of 2649
# working on buffer 2452 of 2649
# working on buffer 2453 of 2649
# working on buffer 2454 of 2649
# working on buffer 2455 of 2649
# working on buffer 2456 of 2649
# working on buffer 2457 of 2649
# working on buffer 2458 of 2649
# working on buffer 2459 of 2649
# working on buffer 2460 of 2649
# working on buffer 2461 of 2649
# working on buffer 2462 of 2649
# working on buffer 2463 of 2649
# working on buffer 2464 of 2649
# working on buffer 2465 of 2649
# working on buffer 2466 of 2649
# working on buffer 2467 of 2649
# working on buffer 2468 of 2649
# working on buffer 2469 of 2649
# working on buffer 2470 of 2649
# working on buffer 2471 of 2649
# working on buffer 2472 of 2649
# working on buffer 2473 of 2649
# working on buffer 2474 of 2649
# working on buffer 2475 of 2649
# working on buffer 2476 of 2649
# working on buffer 2477 of 2649
# working on buffer 2478 of 2649
# working on buffer 2479 of 2649
# working on buffer 2480 of 2649
# working on buffer 2481 of 2649
# working on buffer 2482 of 2649
# working on buffer 2483 of 2649
# working on buffer 2484 of 2649
# working on buffer 2485 of 2649
# working on buffer 2486 of 2649
# working on buffer 2487 of 2649
# working on buffer 2488 of 2649
# working on buffer 2489 of 2649
# working on buffer 2490 of 2649
# working on buffer 2491 of 2649
# working on buffer 2492 of 2649
# working on buffer 2493 of 2649
# working on buffer 2494 of 2649
# working on buffer 2495 of 2649
# working on buffer 2496 of 2649
# working on buffer 2497 of 2649
# working on buffer 2498 of 2649
# working on buffer 2499 of 2649
# working on buffer 2500 of 2649
# working on buffer 2501 of 2649
# working on buffer 2502 of 2649
# working on buffer 2503 of 2649
# working on buffer 2504 of 2649
# working on buffer 2505 of 2649
# working on buffer 2506 of 2649
# working on buffer 2507 of 2649
# working on buffer 2508 of 2649
# working on buffer 2509 of 2649
# working on buffer 2510 of 2649
# working on buffer 2511 of 2649
# working on buffer 2512 of 2649
# working on buffer 2513 of 2649
# working on buffer 2514 of 2649
# working on buffer 2515 of 2649
# working on buffer 2516 of 2649
# working on buffer 2517 of 2649
# working on buffer 2518 of 2649
# working on buffer 2519 of 2649
# working on buffer 2520 of 2649
# working on buffer 2521 of 2649
# working on buffer 2522 of 2649
# working on buffer 2523 of 2649
# working on buffer 2524 of 2649
# working on buffer 2525 of 2649
# working on buffer 2526 of 2649
# working on buffer 2527 of 2649
# working on buffer 2528 of 2649
# working on buffer 2529 of 2649
# working on buffer 2530 of 2649
# working on buffer 2531 of 2649
# working on buffer 2532 of 2649
# working on buffer 2533 of 2649
# working on buffer 2534 of 2649
# working on buffer 2535 of 2649
# working on buffer 2536 of 2649
# working on buffer 2537 of 2649
# working on buffer 2538 of 2649
# working on buffer 2539 of 2649
# working on buffer 2540 of 2649
# working on buffer 2541 of 2649
# working on buffer 2542 of 2649
# working on buffer 2543 of 2649
# working on buffer 2544 of 2649
# working on buffer 2545 of 2649
# working on buffer 2546 of 2649
# working on buffer 2547 of 2649
# working on buffer 2548 of 2649
# working on buffer 2549 of 2649
# working on buffer 2550 of 2649
# working on buffer 2551 of 2649
# working on buffer 2552 of 2649
# working on buffer 2553 of 2649
# working on buffer 2554 of 2649
# working on buffer 2555 of 2649
# working on buffer 2556 of 2649
# working on buffer 2557 of 2649
# working on buffer 2558 of 2649
# working on buffer 2559 of 2649
# working on buffer 2560 of 2649
# working on buffer 2561 of 2649
# working on buffer 2562 of 2649
# working on buffer 2563 of 2649
# working on buffer 2564 of 2649
# working on buffer 2565 of 2649
# working on buffer 2566 of 2649
# working on buffer 2567 of 2649
# working on buffer 2568 of 2649
# working on buffer 2569 of 2649
# working on buffer 2570 of 2649
# working on buffer 2571 of 2649
# working on buffer 2572 of 2649
# working on buffer 2573 of 2649
# working on buffer 2574 of 2649
# working on buffer 2575 of 2649
# working on buffer 2576 of 2649
# working on buffer 2577 of 2649
# working on buffer 2578 of 2649
# working on buffer 2579 of 2649
# working on buffer 2580 of 2649
# working on buffer 2581 of 2649
# working on buffer 2582 of 2649
# working on buffer 2583 of 2649
# working on buffer 2584 of 2649
# working on buffer 2585 of 2649
# working on buffer 2586 of 2649
# working on buffer 2587 of 2649
# working on buffer 2588 of 2649
# working on buffer 2589 of 2649
# working on buffer 2590 of 2649
# working on buffer 2591 of 2649
# working on buffer 2592 of 2649
# working on buffer 2593 of 2649
# working on buffer 2594 of 2649
# working on buffer 2595 of 2649
# working on buffer 2596 of 2649
# working on buffer 2597 of 2649
# working on buffer 2598 of 2649
# working on buffer 2599 of 2649
# working on buffer 2600 of 2649
# working on buffer 2601 of 2649
# working on buffer 2602 of 2649
# working on buffer 2603 of 2649
# working on buffer 2604 of 2649
# working on buffer 2605 of 2649
# working on buffer 2606 of 2649
# working on buffer 2607 of 2649
# working on buffer 2608 of 2649
# working on buffer 2609 of 2649
# working on buffer 2610 of 2649
# working on buffer 2611 of 2649
# working on buffer 2612 of 2649
# working on buffer 2613 of 2649
# working on buffer 2614 of 2649
# working on buffer 2615 of 2649
# working on buffer 2616 of 2649
# working on buffer 2617 of 2649
# working on buffer 2618 of 2649
# working on buffer 2619 of 2649
# working on buffer 2620 of 2649
# working on buffer 2621 of 2649
# working on buffer 2622 of 2649
# working on buffer 2623 of 2649
# working on buffer 2624 of 2649
# working on buffer 2625 of 2649
# working on buffer 2626 of 2649
# working on buffer 2627 of 2649
# working on buffer 2628 of 2649
# working on buffer 2629 of 2649
# working on buffer 2630 of 2649
# working on buffer 2631 of 2649
# working on buffer 2632 of 2649
# working on buffer 2633 of 2649
# working on buffer 2634 of 2649
# working on buffer 2635 of 2649
# working on buffer 2636 of 2649
# working on buffer 2637 of 2649
# working on buffer 2638 of 2649
# working on buffer 2639 of 2649
# working on buffer 2640 of 2649
# working on buffer 2641 of 2649
# working on buffer 2642 of 2649
# working on buffer 2643 of 2649
# working on buffer 2644 of 2649
# working on buffer 2645 of 2649
# working on buffer 2646 of 2649
# working on buffer 2647 of 2649
# working on buffer 2648 of 2649
# working on buffer 2649 of 2649
# Calculating...
# Saving data...
# file saved at: c:\Users\Sjoer\AAA-Python\Insecten in huis\IIH_Repo\Bijlage 1, Definitief\Scripts/Output/TestInput_LGN2018_100.xlsx
